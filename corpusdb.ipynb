# %% [markdown]
# # What if there is no (maintained) Python library?
#
# Corpus-DB - a textual corpus database for the digital humanities by  @j0_0n (Jonathan Reeve) - provides a small API at http://corpus-db.org/docs

# %% [markdown]
# Since there's no Python library written especially for it, the general purpose library for talking to APIs is requests. If you haven't installed it yet, [open a terminal](https://github.com/GCDigitalFellows/installdri.github.io/blob/master/anaconda.md) and type:
# ```bash
# conda install requests -y
# ```

# %%
#let's import requests
import requests

# %%
#let's get all the books for jane austen
r = requests.get("http://corpus-db.org/api/author/Austen, Jane")

# %%
# what's in r?
r
# Out:
# <Response [200]>

# %%
#200 means nothing broke, but what's in r?
r.json()
# Out:
# [{'': '102',
#   'LCC': "{'PR'}",
#   '_repo': 'Persuasion_105',
#   '_version': '0.2.0',
#   'alternative_title': '',
#   'author': 'Austen, Jane',
#   'authoryearofbirth': '1775',
#   'authoryearofdeath': '1817',
#   'contributor': '',
#   'covers': "[{'cover_type': 'archival', 'image_path': 'epub/cover.jpeg'}]",
#   'creator': "{'author': {'agent_name': 'Austen, Jane', 'birthdate': 1775, 'deathdate': 1817, 'gutenberg_agent_id': '68', 'url': 'http://www.gutenberg.org/2009/agents/68', 'wikipedia': 'http://en.wikipedia.org/wiki/Jane_Austen'}}",
#   'description': "Persuasion is Jane Austen's last completed novel, published posthumously. She began it soon after she had finished Emma and completed it in August 1816. Persuasion was published in December 1817, but is dated 1818. The author died earlier in 1817.\nAs the Napoleonic Wars come to an end in 1814, Admirals and Captains of the Royal Navy are put ashore, their work done. Anne Elliot meets Captain Frederick Wentworth after seven years, by the chance of his sister and brother-in-law renting her father's estate, while she stays for a few months with her married sister, living nearby. They fell in love the first time, but she broke off the engagement.\nBesides the theme of persuasion, the novel evokes other topics, with which Austen was familiar: the Royal Navy, in which two of Jane Austen's brothers rose to the rank of admiral; and the superficial social life of Bath. It is portrayed extensively and serves as a setting for the second half of Persuasion. In many respects, Persuasion marks a break with Austen's previous works, both in the more biting, even irritable satire directed at some of the novel's characters and in the regretful, resigned outlook of its otherwise admirable heroine, Anne Elliot, in the first part of the story. Against this is set the energy and appeal of the Royal Navy, which symbolises for Anne and the reader the possibility of a more outgoing, engaged, and fulfilling life, and it is this worldview which triumphs for the most part at the end of the novel.\nPersuasion is linked to Northanger Abbey not only by the fact that the two books were originally bound up in one volume and published together, but also because both stories are set partly in Bath, a fashionable city with which Austen was well acquainted, having lived there from 1801 to 1805.\n From Wikipedia (CC BY-SA).",
#   'downloads': '2514',
#   'edition_identifiers': "{'edition_id': 'http://www.gutenberg.org/ebooks/105#Persuasion'}",
#   'edition_note': '',
#   'filename': '/run/media/jon/SAMSUNG/gitenberg/Persuasion_105/105.txt',
#   'formats': "{'text/plain; charset=us-ascii': 'http://www.gutenberg.org/files/105/105.txt', 'application/x-mobipocket-ebook': 'http://www.gutenberg.org/ebooks/105.kindle.images', 'text/html; charset=iso-8859-1': 'http://www.gutenberg.org/files/105/105-h/105-h.htm', 'application/zip': 'http://www.gutenberg.org/files/105/105.zip', 'application/rdf+xml': 'http://www.gutenberg.org/ebooks/105.rdf', 'application/epub+zip': 'http://www.gutenberg.org/ebooks/105.epub.noimages', 'text/plain; charset=iso-8859-1': 'http://www.gutenberg.org/files/105/105-8.txt', 'text/plain': 'http://www.gutenberg.org/ebooks/105.txt.utf-8'}",
#   'gutenberg_bookshelf': '',
#   'gutenberg_issued': '1994-02-01',
#   'gutenberg_type': 'Text',
#   'id': '105.0',
#   'identifiers': "{'gutenberg': '105', 'wikidata': 'Q333179'}",
#   'jmdate': '2012-09-16',
#   'language_note': '',
#   'languages': "['en']",
#   'lcsh': "{'Love stories', '
'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/ontology/Work\'}, {\'type\': \'uri\', \'value\': \'http://www.wikidata.org/entity/Q571\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/WrittenCommunication106349220\'}, {\'type\': \'uri\', \'value\': \'http://purl.org/ontology/bibo/Book\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Writing106362953\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Wikicat1817Novels\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/WikicatNovelsByJaneAusten\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/WikicatSentimentalNovels\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/ontology/WrittenWork\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Novel106367879\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Wikicat1818Novels\'}, {\'type\': \'uri\', \'value\': \'http://schema.org/Book\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Communication100033020\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Abstraction100002137\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/WikicatEnglishNovels\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/ontology/Book\'}, {\'type\': \'uri\', \'value\': \'http://schema.org/CreativeWork\'}, {\'type\': \'uri\', \'value\': \'http://www.wikidata.org/entity/Q386724\'}, {\'type\': \'uri\', \'value\': \'http://umbel.org/umbel/rc/Book_CW\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Fiction106367107\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/LiteraryComposition106364329\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/Book\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/WikicatBritishNovels\'}], \'http://www.w3.org/2000/01/rdf-schema#label\': [{\'type\': \'literal\', \'value\': \'Persuasion (novel)\', \'lang\': \'en\'}, {\'type\': \'literal\', \'value\': \'اقناع\', \'lang\': \'ar\'}, {\'type\': \'literal\', \'value\': \'Persuasión (novela)\', \'lang\': \'es\'}, {\'type\': \'literal\', \'value\': \'Доводы рассудка\', \'lang\': \'ru\'}, {\'type\': \'literal\', \'value\': \'Überredung\', \'lang\': \'de\'}, {\'type\': \'literal\', \'value\': \'Persuasão (livro)\', \'lang\': \'pt\'}, {\'type\': \'literal\', \'value\': \'Persuasione (romanzo)\', \'lang\': \'it\'}, {\'type\': \'literal\', \'value\': \'Persuasion\', \'lang\': \'nl\'}, {\'type\': \'literal\', \'value\': \'Perswazje\', \'lang\': \'pl\'}, {\'type\': \'literal\', \'value\': \'説得 (小説)\', \'lang\': \'ja\'}, {\'type\': \'literal\', \'value\': \'Persuasion (roman)\', \'lang\': \'fr\'}, {\'type\': \'literal\', \'value\': \'勸導 (小說)\', \'lang\': \'zh\'}], \'http://www.w3.org/2000/01/rdf-schema#comment\': [{\'type\': \'literal\', \'value\': \'Persuasión es la última novela escrita por Jane Austen. La empezó a escribir poco tiempo después de haber terminado Emma, la terminó de escribir en agosto de 1816. Austen murió a la edad de 41 años en 1817, no obstante Persuasión fue publicada como trabajo póstumo en 1818.Persuasión está conectada con La abadía de Northanger no solamente por haber sido publicada junto a ésta en un solo tomo dos años más tarde, sino también porque ambas historias toman lugar en Bath, balneario al que Jane acudía en aquella época.\', \'lang\': \'es\'}, {\'type\': \'literal\', \'value\': \'اقناع (بالإنجليزية: Persuasion) لجاين أوستن، هي آخر رواية نشرتها اوستن. بدأت بكتابة الرواية بعدما انتهت كتابة رواية إيما، حيث انهتها في أغسطس 1816. ماتت اوستن في 1817 عن عمر ينازه 41. ولكن لم تنشر هذه الرواية حتى العام 1818.رواية الإقناع مرتبطة برواية أخرى لجاين وهي مرتبطة بروايتها كنيسة نورث هانجر، ليس لأنهما في الأصل نشرا معاً في كتاب واحد ولكن أيضاً تدور قصة الروايتين في باث، حيث قطنت هناك اوستن من 1801  ...
#   'wp_literary_genres': '',
#   'wp_publication_date': '',
#   'wp_subjects': "['Novels_about_nobility', 'John_Murray_(publisher)_books', 'British_novels', '1818_novels', 'Novels_published_posthumously', 'Love_stories', 'Novels_by_Jane_Austen', 'Novels_set_in_Somerset', 'Books_about_persuasion']"},
#  {'': '116',
#   'LCC': "{'PR'}",
#   '_repo': 'Northanger-Abbey_121',
#   '_version': '0.2.0',
#   'alternative_title': '',
#   'author': 'Austen, Jane',
#   'authoryearofbirth': '1775',
#   'authoryearofdeath': '1817',
#   'contributor': '',
#   'covers': "[{'cover_type': 'generated', 'image_path': 'cover.png'}]",
#   'creator': "{'author': {'agent_name': 'Austen, Jane', 'birthdate': 1775, 'deathdate': 1817, 'gutenberg_agent_id': '68', 'url': 'http://www.gutenberg.org/2009/agents/68', 'wikipedia': 'http://en.wikipedia.org/wiki/Jane_Austen'}}",
#   'description': "For films named Northanger Abbey, see Northanger Abbey (1986 film) or Northanger Abbey (2007 film).\nNorthanger Abbey /ˈnɔːrθˌæŋɡər/ was the first of Jane Austen's novels to be completed for publication, though she had previously made a start on Sense and Sensibility and Pride and Prejudice. According to Cassandra Austen's Memorandum, Susan (as it was first called) was written circa 1798–99. It was revised by Austen for the press in 1803, and sold in the same year for £10 to a London bookseller, Crosby & Co., who decided against publishing. In the spring of 1816, the bookseller was content to sell it back to the novelist's brother, Henry Austen, for the exact sum—£10—that he had paid for it at the beginning, not knowing that the writer was by then the author of four popular novels.\nThe novel was further revised by Austen in 1816/17, with the intention of having it published. Among other changes, the lead character's name was changed from Susan to Catherine, and Austen retitled the book Catherine as a result.\nAusten died in July 1817. Northanger Abbey (as the novel was now called) was brought out posthumously in late December 1817 (1818 given on the title page), as the first two volumes of a four-volume set that also featured another previously unpublished Austen novel, Persuasion. Neither novel was published under the title Jane Austen had given it; the title Northanger Abbey is presumed to have been the invention of Henry Austen, who had arranged for the book's publication.\n From Wikipedia (CC BY-SA).",
#   'downloads': '2006',
#   'edition_identifiers': "{'edition_id': 'http://www.gutenberg.org/ebooks/121#Northanger-Abbey'}",
#   'edition_note': '',
#   'filename': '/run/media/jon/SAMSUNG/gitenberg/Northanger-Abbey_121/121.txt',
#   'formats': "{'text/html; charset=utf-8': 'http://www.gutenberg.org/files/121/121-h/121-h.htm', 'text/plain; charset=us-ascii': 'http://www.gutenberg.org/files/121/121.txt', 'text/plain; charset=utf-8': 'http://www.gutenberg.org/files/121/121-0.txt', 'application/zip': 'http://www.gutenberg.org/files/121/121-0.zip', 'application/rdf+xml': 'http://www.gutenberg.org/ebooks/121.rdf', 'application/epub+zip': 'http://www.gutenberg.org/ebooks/121.epub.noimages', 'application/x-mobipocket-ebook': 'http://www.gutenberg.org/ebooks/121.kindle.images'}",
#   'gutenberg_bookshelf': 'Gothic Fiction',
#   'gutenberg_issued': '1994-04-01',
#   'gutenberg_type': 'Text',
#   'id': '121.0',
#   'identifiers': "{'gutenberg': '121', 'wikidata': 'Q477508'}",
#   'jmdate': '2010-01-21',
#   'language_note': '',
#   'languages': "['en']",
#   'lcsh': "{'Love stories', 'Gothic fiction (Literary genre)', 'Young women -- Fiction', 'Gentry -- England -- Fiction', 'Marriage -- Economic aspects -- Fiction', 'Satire', 'Horror tales -- Appreciation -- Fiction', 'England -- Fiction', 'England -- Social life and customs -- 19th century -- Fiction', 'Books and reading -- Fiction'}",
#   'production_note': '',
#   'publication_date': '',
#   'publication_note': '',
#   'publisher': 'Project Gutenberg',
#   'releaseDate': '',
#   'rights': 'Public domain in the USA.',
#   'rights_url': 'http://creativecommons.org/about/pdm',
#   'series_note': '',
#   'subjects': "['Love stories', 'Satire', 'Young women -- Fiction', 'England -- Fiction', 'Horror tales -- Appreciation -- Fiction', 'Books and reading -- Fiction', 'Gothic fiction']",
#   'summary': '',
#   'tableOfContents': '',
#   'title': 'Northanger Abbey',
#   'titlepage_image': '',
#   'type': 'Text',
#   'url': 'http://www.gutenberg.org/ebooks/121',
#   'wikipedia': "['https://fi.wikipedia.org/wiki/Northanger_Abbey', 'https://fa.wikipedia.org/wiki/%D9%86%D9%88%D8%B1%D8%AB%D9%86%DA%AF%D8%B1_%D8%A7%D8%A8%DB%8C', 'https://ja.wikipedia.org/wiki/%E3%83%8E%E3%83%BC%E3%82%B5%E3%83%B3%E3%82%AC%E3%83%BC%E3%83%BB%E3%82%A2%E3%83%93%E3%83%BC', 'https://pt.wikipedia.org/wiki/Northanger_Abbey', 'https://es.wikipedia.org/wiki/La_abad%C3%ADa_de_Northanger', 'https://en.wikipedia.org/wiki/Northanger_Abbey', 'https://ru.wikipedia.org/wiki/%D0%9D%D0%BE%D1%80%
'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Organism100004475\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/Book\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Parody106780309\'}, {\'type\': \'uri\', \'value\': \'http://schema.org/CreativeWork\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/LivingThing100004258\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Message106598915\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Fiction106367107\'}, {\'type\': \'uri\', \'value\': \'http://schema.org/Book\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Wit106776138\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/WikicatGothicNovels\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Wikicat1817Novels\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Novel106367879\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Object100002684\'}], \'http://www.w3.org/2000/01/rdf-schema#label\': [{\'type\': \'literal\', \'value\': \'Northanger Abbey\', \'lang\': \'nl\'}, {\'type\': \'literal\', \'value\': "L\'Abbaye de Northanger", \'lang\': \'fr\'}, {\'type\': \'literal\', \'value\': \'Northanger Abbey\', \'lang\': \'en\'}, {\'type\': \'literal\', \'value\': \'ノーサンガー・アビー\', \'lang\': \'ja\'}, {\'type\': \'literal\', \'value\': \'La abadía de Northanger\', \'lang\': \'es\'}, {\'type\': \'literal\', \'value\': "L\'abbazia di Northanger", \'lang\': \'it\'}, {\'type\': \'literal\', \'value\': \'Opactwo Northanger\', \'lang\': \'pl\'}, {\'type\': \'literal\', \'value\': \'Die Abtei von Northang ...
#   'wp_literary_genres': '',
#   'wp_publication_date': '',
#   'wp_subjects': "['Novels_by_Jane_Austen', 'Novels_set_in_Somerset', '1817_novels', 'Fictional_houses', 'British_novels', 'British_bildungsromans', 'Parodies', 'Gothic_novels', 'Novels_about_nobility', 'Novels_published_posthumously']"},
#  {'': '134',
#   'LCC': "{'PR'}",
#   '_repo': 'Mansfield-Park_141',
#   '_version': '0.2.0',
#   'alternative_title': '',
#   'author': 'Austen, Jane',
#   'authoryearofbirth': '1775',
#   'authoryearofdeath': '1817',
#   'contributor': '',
#   'covers': "[{'cover_type': 'generated', 'image_path': 'cover.png'}]",
#   'creator': "{'author': {'agent_name': 'Austen, Jane', 'birthdate': 1775, 'deathdate': 1817, 'gutenberg_agent_id': '68', 'url': 'http://www.gutenberg.org/2009/agents/68', 'wikipedia': 'http://en.wikipedia.org/wiki/Jane_Austen'}}",
#   'description': "Mansfield Park is the third novel by Jane Austen, written at Chawton Cottage between February 1811 and 1813. It was published in May 1814 by Thomas Egerton, who published Jane Austen's two earlier novels, Sense and Sensibility and Pride and Prejudice. When the novel reached a second edition in 1816, its publication was taken over by John Murray, who also published its successor, Emma.\n From Wikipedia (CC BY-SA).",
#   'downloads': '2012',
#   'edition_identifiers': "{'edition_id': 'http://www.gutenberg.org/ebooks/141#Mansfield-Park'}",
#   'edition_note': '',
#   'filename': '/run/media/jon/SAMSUNG/gitenberg/Mansfield-Park_141/141.txt',
#   'formats': "{'text/plain; charset=utf-8': 'http://www.gutenberg.org/files/141/141-0.txt', 'text/plain; charset=us-ascii': 'http://www.gutenberg.org/files/141/141.txt', 'application/pdf': 'http://www.gutenberg.org/files/141/141-pdf.pdf', 'text/html; charset=utf-8': 'http://www.gutenberg.org/files/141/141-h.zip', 'application/rdf+xml': 'http://www.gutenberg.org/ebooks/141.rdf', 'application/epub+zip': 'http://www.gutenberg.org/ebooks/141.epub.noimages', 'application/x-mobipocket-ebook': 'http://www.gutenberg.org/ebooks/141.kindle.noimages'}",
#   'gutenberg_bookshelf': '',
#   'gutenberg_issued': '1994-06-01',
#   'gutenberg_type': 'Text',
#   'id': '141.0',
#   'identifiers': "{'gutenberg': '141', 'wikidata': 'Q469690'}",
#   'jmdate': '',
#   'language_note': '',
#   'languages': "['en']",
#   'lcsh': "{'Love stories', 'Young women -- Fiction', 'Domestic fiction', 'Children of the rich -- Fiction', 'Country homes -- Fiction', 'Adoptees -- Fiction', 'Uncles -- Fiction', 'Cousins -- Fiction', 'England -- Fiction'}",
#   'production_note': '',
#   'publication_date': '',
#   'publication_note': '',
#   'publisher': 'Project Gutenberg',
#   'releaseDate': '',
#   'rights': 'Public domain in the USA.',
#   'rights_url': 'http://creativecommons.org/about/pdm',
#   'series_note': '',
#   'subjects': '',
#   'summary': '',
#   'tableOfContents': '',
#   'title': 'Mansfield Park',
#   'titlepage_image': '',
#   'type': 'Text',
#   'url
'}, {\'type\': \'literal\', \'value\': \'Mansfield Park\', \'lang\': \'en\'}, {\'type\': \'literal\', \'value\': \'マンスフィールド・パーク\', \'lang\': \'ja\'}, {\'type\': \'literal\', \'value\': \'Мэнсфилд-парк\', \'lang\': \'ru\'}, {\'type\': \'literal\', \'value\': \'مانسفيلد بارك\', \'lang\': \'ar\'}, {\'type\': \'literal\', \'value\': \'Mansfield Park\', \'lang\': \'it\'}, {\'type\': \'literal\', \'value\': \'Mansfield Park\', \'lang\': \'pl\'}, {\'type\': \'literal\', \'value\': \'Mansfield Park\', \'lang\': \'pt\'}, {\'type\': \'literal\', \'value\': \'Mansfield Park\', \'lang\': \'de\'}, {\'type\': \'literal\', \'value\': \'曼斯菲爾德莊園\', \'lang\': \'zh\'}], \'http://www.w3.org/2000/01/rdf-schema#comment\': [{\'type\': \'literal\', \'value\': \'Mansfield Park – powieść angielskiej pisarki Jane Austen, wydana w 1814 roku. Opowiada o losach Fanny Price, skromnej i cichej, niezamożnej dziewczyny wychowywanej w domu zamożnych krewnych - tytułowej posiadłości Mansfield Park. Mansfield Park ukazał się jako trzecia powieść Jane Austen, po cieszących się ogromną popularnością Rozważnej i romantycznej i Dumie i uprzedzeniu. Mansfield Park otwiera drugi okres w twórczości Jane Austen - powieści, które powstały po sukcesie Rozważnej i romantycznej. Pisarka pracowała nad nią w lat ...
#   'wp_literary_genres': '',
#   'wp_publication_date': '',
#   'wp_subjects': "['Novels_by_Jane_Austen', 'British_novels_adapted_into_films', 'Novels_adapted_into_plays', 'Novels_about_nobility', '1814_novels']"},
#  {'': '151',
#   'LCC': "{'PR'}",
#   '_repo': 'Emma_158',
#   '_version': '0.2.0',
#   'alternative_title': '',
#   'author': 'Austen, Jane',
#   'authoryearofbirth': '1775',
#   'authoryearofdeath': '1817',
#   'contributor': '',
#   'covers': "[{'cover_type': 'generated', 'image_path': 'cover.png'}]",
#   'creator': "{'author': {'agent_name': 'Austen, Jane', 'birthdate': 1775, 'deathdate': 1817, 'gutenberg_agent_id': '68', 'url': 'http://www.gutenberg.org/2009/agents/68', 'wikipedia': 'http://en.wikipedia.org/wiki/Jane_Austen'}}",
#   'description': 'Emma, by Jane Austen, is a novel about youthful hubris and the perils of misconstrued romance. The novel was first published in December 1815. As in her other novels, Austen explores the concerns and difficulties of genteel women living in Georgian-Regency England; she also creates a lively comedy of manners among her characters.\nBefore she began the novel, Austen wrote, "I am going to take a heroine whom no one but myself will much like." In the first sentence she introduces the title character as "Emma Woodhouse, handsome, clever, and rich." Emma is spoiled, headstrong, and self-satisfied; she greatly overestimates her own matchmaking abilities; she is blind to the dangers of meddling in other people\'s lives; and her imagination and perceptions often lead her astray.\nThis novel has been adapted for several films, many television programs, and a long list of stage plays.\n From Wikipedia (CC BY-SA).',
#   'downloads': '7991',
#   'edition_identifiers': "{'edition_id': 'http://www.gutenberg.org/ebooks/158#Emma'}",
#   'edition_note': '',
#   'filename': '/run/media/jon/SAMSUNG/gitenberg/Emma_158/158.txt',
#   'formats': "{'text/html; charset=utf-8': 'http://www.gutenberg.org/files/158/158-h/158-h.htm', 'text/plain; charset=us-ascii': 'http://www.gutenberg.org/files/158/158.txt', 'application/pdf': 'http://www.gutenberg.org/files/158/158-pdf.pdf', 'text/plain; charset=utf-8': 'http://www.gutenberg.org/files/158/158-0.txt', 'application/zip': 'http://www.gutenberg.org/files/158/158-pdf.zip', 'application/rdf+xml': 'http://www.gutenberg.org/ebooks/158.rdf', 'application/epub+zip': 'http://www.gutenberg.org/ebooks/158.epub.noimages', 'application/x-mobipocket-ebook': 'http://www.gutenberg.org/ebooks/158.kindle.images'}",
#   'gutenberg_bookshelf': '',
#   'gutenberg_issued': '1994-08-01',
#   'gutenberg_type': 'Text',
#   'id': '158.0',
#   'identifiers': "{'gutenberg': '158', 'wikidata': 'Q223880'}",
#   'jmdate': '',
#   'language_note': '',
#   'languages': "['en']",
#   'lcsh': "{'Love stories', 'Bildungsromans', 'Young women -- Fiction', 'Humorous stories', 'Female friendship -- Fiction', 'Mate selection -- Fiction', 'Fathers and daughters -- Fiction', 'England -- Fiction'}",
#   'production_note': '',
#   'publication_date': '',
#   'publication_note': '',
#   'publisher
'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/WikicatBooksAdaptedIntoFilms\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Publication106589574\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/ontology/Work\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Product104007894\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/WikicatJaneAustenCharacters\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/YagoPermanentlyLocatedEntity\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Cognition100023271\'}, {\'type\': \'uri\', \'value\': \'http://www.w3.org/2002/07/owl#Thing\'}, {\'type\': \'uri\', \'value\': \'http://schema.org/Book\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Imagination105625465\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Event100029378\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/ImaginaryBeing109483738\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/ontology/WrittenWork\'}, {\'type\': \'uri\', \'value\': \'http://schema.org/CreativeWork\'}, {\'type\': \'uri\', \'value\': \'http://www.wikidata.org/entity/Q386724\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Book106410904\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/PhysicalEntity100001930\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Show106619065\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/WikicatBritishNovelsAdaptedIntoFilms\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/PsychologicalFeature100023100\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Movie106613686\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/WikicatNovelsAdaptedIntoFilms\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/SocialEvent107288639\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Creativity105624700\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Creation103129123\'}, {\'type\': \'uri\', \'value\': \'http://purl.org/ontology/bibo/Book\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Object100002684\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/class/yago/Artifact100021939\'}], \'http://www.w3.org/2000/01/rdf-schema#label\': [{\'type\': \'literal\', \'value\': \'إيما\', \'lang\': \'ar\'}, {\'type\': \'literal\', \'value\': \'エマ (小説)\', \'lang\': \'ja\'}, {\'type\': \'literal\', \'value\': \'愛瑪\', \'lang\': \'zh\'}, {\'type\': \'literal\', \'value\': \'Emma\', \'lang\': \'pt\'}, {\'type\': \'literal\', \'value\': \'Emma (roman)\', \'lang\': \'fr\'}, {\'type\': \'literal\', \'value\': \'Эмма (роман)\', \'lang\': \'ru\'}, {\'type\': \'literal\', \'value\': \'Emma (roman)\', \'lang\': \'nl\'}, {\'type\': \'literal\', \'value\': \'Emma (novel)\', \'lang\': \'en\'}, {\'type\': \'literal\', \'value\': \'Emma\', \'lang\': \'es\'}, {\'type\': \'literal\', \'value\': \'Emma (Roman)\', \'lang\': \'de\'}, {\'type\': \'literal\', \'value\': \'Emma (romanzo)\', \'lang\': \'it\'}, {\'type\': \'literal\', \'value\': \'Emma (powieść)\', \'lang\': \'pl\'}], \'http://www.w3.org/2000/01/rdf-schema#comment\': [{\'type\': \'literal\', \'value\': \'Emma – powieść angielskiej  ...
#   'wp_literary_genres': "['Novel_of_manners']",
#   'wp_publication_date': '',
#   'wp_subjects': "['Novels_by_Jane_Austen', 'Novels_about_nobility', 'John_Murray_(publisher)_books', '1815_novels', 'British_novels_adapted_into_films', 'British_comedy_novels', 'British_bildungsromans', 'Novels_set_in_England']"},
#  {'': '154',
#   'LCC': "{'PR'}",
#   '_repo': 'Sense-and-Sensibility_161',
#   '_version': '0.2.0',
#   'alternative_title': '',
#   'author': 'Austen, Jane',
#   'authoryearofbirth': '1775',
#   'authoryearofdeath': '1817',
#   'contributor': '',
#   'covers': "[{'cover_type': 'generated', 'image_path': 'cover.png'}]",
#   'creator': "{'author': {'agent_name': 'Austen, Jane', 'birthdate': 1775, 'deathdate': 1817, 'gutenberg_agent_id': '68', 'url': 'http://www.gutenberg.org/2009/agents/68', 'wikipedia': 'http://en.wikipedia.org/wiki/Jane_Austen'}}",
#   'description': 'Sense and Sensibility is a novel by Jane Austen, and was her first published work when it appeared in 1811 under the pseudonym "A Lady". A work of romantic fiction, better known as a comedy of manners, Sense and Sensibility is set in southwest England, London and Kent between 1792 and 1797, and portrays the life and loves of the Dashwood sisters, Elinor and Marianne. The novel follows the young ladies to their new home, a meagre cottage on a distant relative\'s property, where they experience love, romance and heartbreak.\n From Wikipedia (CC BY-SA).',
#   'downloads': '3626',
#   'edition_identifiers': "{'edition_id': 'http://www.gutenberg.org/ebooks/161#Sense-and-Sensibility'}",
#   'edition_note': '',
#   'filename': '/run/media/jon/SAMSUNG/gitenberg/Sense-and-Sensibility_161/161.txt',
#   'formats': "{'application/x-mobipocket-ebook': 'http://www.gutenberg.org/ebooks
 'text/plain; charset=us-ascii': 'http://www.gutenberg.org/files/37431/37431.txt', 'text/plain': 'http://www.gutenberg.org/ebooks/37431.txt.utf-8', 'application/zip': 'http://www.gutenberg.org/files/37431/37431.zip', 'text/plain; charset=iso-8859-1': 'http://www.gutenberg.org/files/37431/37431-8.txt', 'application/epub+zip': 'http://www.gutenberg.org/ebooks/37431.epub.images', 'text/html; charset=iso-8859-1': 'http://www.gutenberg.org/files/37431/37431-h/37431-h.htm', 'application/x-mobipocket-ebook': 'http://www.gutenberg.org/ebooks/37431.kindle.noimages'}",
#   'gutenberg_bookshelf': '',
#   'gutenberg_issued': '',
#   'gutenberg_type': '',
#   'id': '37431.0',
#   'identifiers': '',
#   'jmdate': '',
#   'language_note': '',
#   'languages': "['en']",
#   'lcsh': "{'England -- Drama', 'Sisters -- Drama', 'Domestic drama', 'Courtship -- Drama', 'Young women -- Drama', 'Bennet, Elizabeth (Fictitious character) -- Drama', 'Social classes -- Drama', 'Fairy tales -- United States'}",
#   'production_note': '',
#   'publication_date': '',
#   'publication_note': '',
#   'publisher': '',
#   'releaseDate': '',
#   'rights': '',
#   'rights_url': '',
#   'series_note': '',
#   'subjects': '',
#   'summary': '',
#   'tableOfContents': '',
#   'title': "Pride and Prejudice, a play founded on Jane Austen's novel",
#   'titlepage_image': '',
#   'type': 'Text',
#   'url': '',
#   'wikipedia': '',
#   'wp_info': '',
#   'wp_literary_genres': '',
#   'wp_publication_date': '',
#   'wp_subjects': ''},
#  {'': '36393',
#   'LCC': "{'PR'}",
#   '_repo': '',
#   '_version': '',
#   'alternative_title': '',
#   'author': 'Austen, Jane',
#   'authoryearofbirth': '1775',
#   'authoryearofdeath': '1817',
#   'contributor': '',
#   'covers': '',
#   'creator': '',
#   'description': '',
#   'downloads': '14',
#   'edition_identifiers': '',
#   'edition_note': '',
#   'filename': '/run/media/jon/SAMSUNG/gutenberg-mirror/3/7/6/3/37634/37634-8.txt',
#   'formats': "{'text/html; charset=iso-8859-1': 'http://www.gutenberg.org/files/37634/37634-h/37634-h.htm', 'text/plain': 'http://www.gutenberg.org/ebooks/37634.txt.utf-8', 'application/zip': 'http://www.gutenberg.org/files/37634/37634-8.zip', 'text/plain; charset=iso-8859-1': 'http://www.gutenberg.org/files/37634/37634-8.txt', 'application/epub+zip': 'http://www.gutenberg.org/ebooks/37634.epub.noimages', 'application/rdf+xml': 'http://www.gutenberg.org/ebooks/37634.rdf', 'application/x-mobipocket-ebook': 'http://www.gutenberg.org/ebooks/37634.kindle.noimages'}",
#   'gutenberg_bookshelf': '',
#   'gutenberg_issued': '',
#   'gutenberg_type': '',
#   'id': '37634.0',
#   'identifiers': '',
#   'jmdate': '',
#   'language_note': '',
#   'languages': "['fr']",
#   'lcsh': "{'Love stories', 'Young women -- Fiction', 'Inheritance and succession -- Fiction', 'Domestic fiction', 'Social classes -- Fiction', 'Gentry -- England -- Fiction', 'Mate selection -- Fiction', 'Regency fiction', 'Sisters -- Fiction', 'England -- Fiction', 'England -- Social life and customs -- 19th century -- Fiction'}",
#   'production_note': '',
#   'publication_date': '',
#   'publication_note': '',
#   'publisher': '',
#   'releaseDate': '',
#   'rights': '',
#   'rights_url': '',
#   'series_note': '',
#   'subjects': '',
#   'summary': '',
#   'tableOfContents': '',
#   'title': "Raison et sensibilité, ou les deux manières d'aimer (Tome 4)",
#   'titlepage_image': '',
#   'type': 'Text',
#   'url': '',
#   'wikipedia': '',
#   'wp_info': '',
#   'wp_literary_genres': '',
#   'wp_publication_date': '',
#   'wp_subjects': ''},
#  {'': '40837',
#   'LCC': "{'PR'}",
#   '_repo': '',
#   '_version': '',
#   'alternative_title': '',
#   'author': 'Austen, Jane',
#   'authoryearofbirth': '1775',
#   'authoryearofdeath': '1817',
#   'contributor': '',
#   'covers': '',
#   'creator': '',
#   'description': '',
#   'downloads': '149',
#   'edition_identifiers': '',
#   'edition_note': '',
#   'filename': '/run/media/jon/SAMSUNG/gitenberg/The-Letters-of-Jane-Austen--13-Selected-from-the-compilation-of-her-great-nephew-Edward-Lord-__42078/42078.txt',
#   'formats': "{'image/jpeg': 'http://www.gutenberg.org/cache/epub/42078/pg42078.cover.medium.jpg', 'text/plain; charset=us-ascii': 'http://www.gutenberg.org/files/42078/42078.txt', 'text/plain': 'http://www.gutenberg.org/ebooks/42078.txt.utf-8', 'text/html; charset=iso-8859-1': 'http://www.gutenberg.org/files/42078/42078-h/42078-h.htm', 'application/zip': 'http://www.gutenberg.org/files/42078/42078-8.zip', 'application/rdf+xml': 'http://www.gutenberg.org/ebooks/42078.rdf', 'application/epub+zip': 'http://www.gutenberg.org/ebooks/42078.epub.images', 'text/plain; charset=iso-8859-1': 'http://www.gutenberg.org/files/42078/42078-8.txt', 'application/x-mobipocket-ebook': 'http://www.gutenberg.org/ebooks/42078.kindle.noimages'}",
#   'gutenberg_bookshelf': '',
#   'gutenberg_issued': '',
#   'gutenberg_type': '',
#   'id': '42078.0',
#   'identifiers': '',
#   'jmdate': '',
#   'language_note': '',
#   'languages': "['en']",
#   'lcsh': "{'Austen, Jane, 1775-1817 -- Correspondence', 'Novelists, English -- 19th century -- Correspondence', 'Austen, Cassandra, 1773-1845'}",
#   'production_note': '',
#   'publication_date': '',
#   'publication_note': '',
#   'publisher': '',
#   'releaseDate': '',
#   'rights': '',
#   'rights_url': '',
#   'series_note': '',
#   'subjects': '',
#   'summary': '',
#   'tableOfContents': '',
#   'title': 'The Letters of Jane Austen: Selected from the compilation of her great nephew, Edward, Lord Bradbourne',
#   'titlepage_image': '',
#   'type': 'Text',
#   'url': '',
#   'wikipedia': '',
#   'wp_info': '',
#   'wp_literary_genres': '',
#   'wp_publication_date': '',
#   'wp_subjects': ''},
#  {'': '41430',
#   'LCC': "{'PR'}",
#   '_repo': '',
#   '_version': '',
#   'alternative_title': '',
#   'author': 'Austen, Jane',
#   'authoryearofbirth': '1775',
#   'authoryearofdeath': '1817',
#   'contributor': '',
#   'covers': '',
#   'creator': '',
#   'description': '',
#   'downloads': '1198',
#   'edition_identifiers': '',
#   'edition_note': '',
#   'filename': '/run/media/jon/SAMSUNG/gitenberg/Pride-and-Prejudice_42671/42671.txt',
#   'formats': "{'text/html': 'http://www.gutenberg.org/files/42671/42671-h/42671-h.htm', 'text/plain; charset=us-ascii': 'http://www.gutenberg.org/files/42671/42671.txt', 'text/plain': 'http://www.gutenberg.org/ebooks/42671.txt.utf-8', 'application/zip': 'http://www.gutenberg.org/files/42671/42671-8.zip', 'application/rdf+xml': 'http://www.gutenberg.org/ebooks/42671.rdf', 'application/epub+zip': 'http://www.gutenberg.org/ebooks/42671.epub.noimages', 'text/plain; charset=iso-8859-1': 'http://www.gutenberg.org/files/42671/42671-8.txt', 'application/x-mobipocket-ebook': 'http://www.gutenberg.org/ebooks/42671.kindle.noimages'}",
#   'gutenberg_bookshelf': '',
#   'gutenberg_issued': '',
#   'gutenberg_type': '',
#   'id': '42671.0',
#   'identifiers': '',
#   'jmdate': '',
#   'language_note': '',
#   'languages': "['en']",
#   'lcsh': "{'Love stories', 'Young women -- Fiction', 'Domestic fiction', 'Social classes -- Fiction', 'Courtship -- Fiction', 'Sisters -- Fiction', 'England -- Fiction'}",
#   'production_note': '',
#   'publication_date': '',
#   'publication_note': '',
#   'publisher': '',
#   'releaseDate': '',
#   'rights': '',
#   'rights_url': '',
#   'series_note': '',
#   'subjects': '',
#   'summary': '',
#   'tableOfContents': '',
#   'title': 'Pride and Prejudice',
#   'titlepage_image': '',
#   'type': 'Text',
#   'url': '',
#   'wikipedia': '',
#   'wp_info': '{\'http://www.w3.org/1999/02/22-rdf-syntax-ns#type\': [{\'type\': \'uri\', \'value\': \'http://www.w3.org/2002/07/owl#Thing\'}, {\'type\': \'uri\', \'value\': \'http://www.wikidata.org/entity/Q386724\'}, {\'type\': \'uri\', \'value\': \'http://schema.org/CreativeWork\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/ontology/WrittenWork\'}, {\'type\': \'uri\', \'value\': \'http://schema.org/Book\'}, {\'type\': \'uri\', \'value\': \'http://umbel.org/umbel/rc/Book_CW\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/ontology/Work\'}, {\'type\': \'uri\', \'value\': \'http://purl.org/ontology/bibo/Book\'}, {\'type\': \'uri\', \'value\': \'http://www.wikidata.org/entity/Q571\'}, {\'type\': \'uri\', \'value\': \'http://dbpedia.org/ontology/Book\'}], \'http://www.w3.org/2000/01/rdf-schema#label\': [{\'type\': \'literal\', \'value\': \'Duma i uprzedzenie\', \'lang\': \'pl\'}, {\'type\': \'literal\', \'value\': \'Orgoglio e pregiudizio\', \'lang\': \'it\'}, {\'type\': \'literal\', \'value\': \'高慢と偏見\', \'lang\': \'ja\'}, {\'type\': \'literal\', \'value\': \'Stolz und Vorurteil\', \'lang\': \'de\'}, {\'type\': \'literal\', \'value\': \'傲慢與偏見\', \'lang\': \'zh\'}, {\'type\': \'literal\', \'value\': \'Гордость и предубеждение\', \'lang\': \'ru\'}, {\'type\': \'literal\', \'value\': \'Pride and Prejudice (boek)\', \'lang\': \'nl\'}, {\'type\': \'literal\', \'value\': \'Orgullo y prejuicio (novela)\', \'lang\': \'es\'}, {\'type\': \'literal\', \'value\': \'كبرياء وتحامل (رواية)\', \'lang\': \'ar\'}, {\'type\': \'literal\', \'value\': \'Orgueil et Préjugés\', \'lang\': \'fr\'}, {\'type\': \'literal\', \'value\': \'Orgulho e Preconceito\', \'lang\': \'pt\'}, {\'type\': \'literal\', \'value\': \'Pride and Prejudice\', \'lang\': \'en\'}], \'http://www.w3.org/2000/01/rdf-schema#comment\': [{\'type\': \'literal\', \'value\': "Orgoglio e pregiudizio (Pride and Prejudice) è uno dei più celebri romanzi della scrittrice inglese Jane Austen, pubblicato il 28 gennaio 1813.Il romanzo ha come temi principali (che danno il titolo all\'opera) l\'orgoglio di classe del signor Darcy e il pregiudizio della protagonista Elizabeth Bennet nei confronti di quest\'ultimo. La trama si concentra sulle vicende della famiglia Bennet.", \'lang\': \'it\'}, {\'type\': \'literal\', \'value\': \'Orgullo y prejuicio (en inglés, Pride and Prejudice), publicada por primera vez el 28 de enero de 1813 como una obra anónima, es la más famosa de las novelas de Jane Austen y una de las primeras comedias románticas en la historia de la novela. Su primera frase es, además, una de las más famosas en la literatura inglesa: «Es una verdad mundialmente reconocida que un hombre soltero, poseedor de una gran fortuna, necesita una esposa.»\', \'lang\': \'es\'}, {\'type\': \'literal\', \'value\': \'Pride and Prejudice (br/pt: Orgulho e Preconceito) é um romance da escritora britânica Jane Austen. Publicado pela primeira vez em 1813, na verdade havia sido terminado em 1797, antes de ela completar 21 anos, em Steventon, Hampshire, onde Jane morava com os pais. Originalmente denominado First Impressions, nunca foi publicado sob aquele título; ao fazer a revisão dos escritos, Jane intitulou a obra e a publicou como Pride and Prejudice. Austen pode ter tido em mente o capítulo final do romance de Fanny Burney, Cecilia, chamado "Pride and Prejudice".\', \'lang\': \'pt\'}, {\'type\': \'literal\', \'value\': \'Pride and Prejudice (Ned: Trots en Vooroordeel of Waan en Eigenwaan) is een roman, gepubliceerd in 1813, geschreven door de Britse schrijfster Jane Austen. Ze begon te schrijven aan het originele manuscript van Pride and Prejudice tussen 1796 en 1797, onder de titel First Impressions (met name omdat zij wilde benadrukken dat deze zoveel vooroordelen leveren, zie de Nederlandse vertaling van de titel). Maar een uitgever vond het niet goed genoeg waardoor ze het pas in 1811 herzag. Pride and Prejudice werd voor het eerst gedrukt in januari 1813, twee jaar na Sense and  ...
#   'wp_literary_genres': "['Novel_of_manners']",
#   'wp_publication_date': '1813-01-28',
#   'wp_subjects': "['19th-century_novels', 'Love_stories', 'Novels_set_in_Hertfordshire', '1813_novels', 'British_satirical_novels', 'Pride_and_Prejudice', 'Novels_adapted_into_plays', 'Novels_about_nobility', 'British_novels_adapted_into_films', 'Novels_by_Jane_Austen']"},
#  {'': '43945',
#   'LCC': "{'PR'}",
#   '_repo': '',
#   '_version': '',
#   'alternative_title': '',
#   'author': 'Austen, Jane',
#   'authoryearofbirth': '1775',
#   'authoryearofdeath': '1817',
#   'contributor': '',
#   'covers': '',
#   'creator': '',
#   'description': '',
#   'downloads': '18',
#   'edition_identifiers': '',
#   'edition_note': '',
#   'filename': '/run/media/jon/SAMSUNG/gutenberg-mirror/4/5/1/8/45186/45186-8.txt',
#   'formats': "{'text/html': 'http://www.gutenberg.org/ebooks/45186.html.images', 'application/x-mobipocket-ebook': 'http://www.gutenberg.org/ebooks/45186.kindle.noimages', 'text/plain; charset=iso-8859-1': 'http://www.gutenberg.org/files/45186/45186-8.txt', 'application/epub+zip': 'http://www.gutenberg.org/ebooks/45186.epub.noimages', 'application/rdf+xml': 'http://www.gutenberg.org/ebooks/45186.rdf', 'text/plain': 'http://www.gutenberg.org/ebooks/45186.txt.utf-8'}",
#   'gutenberg_bookshelf': '',
#   'gutenberg_issued': '',
#   'gutenberg_type': '',
#   'id': '45186.0',
#   'identifiers': '',
#   'jmdate': '',
#   'language_note': '',
#   'languages': "['fi']",
#   'lcsh': "{'Love stories', 'Young women -- Fiction', 'Domestic fiction', 'Social classes -- Fiction', 'Courtship -- Fiction', 'Sisters -- Fiction', 'England -- Fiction'}",
#   'production_note': '',
#   'publication_date': '',
#   'publication_note': '',
#   'publisher': '',
#   'releaseDate': '',
#   'rights': '',
#   'rights_url': '',
#   'series_note': '',
#   'subjects': '',
#   'summary': '',
#   'tableOfContents': '',
#   'title': 'Ylpeys ja ennakkoluulo',
#   'titlepage_image': '',
#   'type': 'Text',
#   'url': '',
#   'wikipedia': '',
#   'wp_info': '',
#   'wp_literary_genres': '',
#   'wp_publication_date': '',
#   'wp_subjects': ''}]

# %%
#lets use pandas dor a quick view
import pandas as pd
df = pd.io.json.json_normalize(r.json())
df.head()
# Out:
#            LCC                      _repo _version alternative_title  \
# 0  102  {'PR'}             Persuasion_105    0.2.0
# 1  116  {'PR'}       Northanger-Abbey_121    0.2.0
# 2  134  {'PR'}         Mansfield-Park_141    0.2.0
# 3  151  {'PR'}                   Emma_158    0.2.0
# 4  154  {'PR'}  Sense-and-Sensibility_161    0.2.0
#
#          author authoryearofbirth authoryearofdeath contributor  \
# 0  Austen, Jane              1775              1817
# 1  Austen, Jane              1775              1817
# 2  Austen, Jane              1775              1817
# 3  Austen, Jane              1775              1817
# 4  Austen, Jane              1775              1817
#
#                                               covers  \
# 0  [{'cover_type': 'archival', 'image_path': 'epu...
# 1  [{'cover_type': 'generated', 'image_path': 'co...
# 2  [{'cover_type': 'generated', 'image_path': 'co...
# 3  [{'cover_type': 'generated', 'image_path': 'co...
# 4  [{'cover_type': 'generated', 'image_path': 'co...
#
#                          ...                         tableOfContents  \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                    title titlepage_image  type  \
# 0             Persuasion                  Text
# 1       Northanger Abbey                  Text
# 2         Mansfield Park                  Text
# 3                   Emma                  Text
# 4  Sense and Sensibility                  Text
#
#                                    url  \
# 0  http://www.gutenberg.org/ebooks/105
# 1  http://www.gutenberg.org/ebooks/121
# 2  http://www.gutenberg.org/ebooks/141
# 3  http://www.gutenberg.org/ebooks/158
# 4  http://www.gutenberg.org/ebooks/161
#
#                                            wikipedia  \
# 0  ['https://fi.wikipedia.org/wiki/Viisasteleva_s...
# 1  ['https://fi.wikipedia.org/wiki/Northanger_Abb...
# 2  ['https://fi.wikipedia.org/wiki/Kasvattityt%C3...
# 3  ['https://fi.wikipedia.org/wiki/Emma_(romaani)...
# 4  ['https://fi.wikipedia.org/wiki/J%C3%A4rki_ja_...
#
#                                              wp_info    wp_literary_genres  \
# 0  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 1  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 2  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 3  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...  ['Novel_of_manners']
# 4  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
#
#   wp_publication_date                                        wp_subjects
# 0                      ['Novels_about_nobility', 'John_Murray_(publis...
# 1                      ['Novels_by_Jane_Austen', 'Novels_set_in_Somer...
# 2                      ['Novels_by_Jane_Austen', 'British_novels_adap...
# 3                      ['Novels_by_Jane_Austen', 'Novels_about_nobili...
# 4                      ['Debut_novels', 'Novels_by_Jane_Austen', 'Wor...
#
# [5 rows x 46 columns]

# %%
#but it's a corpus? 
r = requests.get("http://corpus-db.org/api/author/Austen, Jane/fulltext")

# %%
bdf = pd.io.json.json_normalize(r.json())
bdf.head()
# Out:
#     id                                               text
# 0  105  by Al Haines.\n\n\n\n\n\n\n\n\n\n\nPersuasion\...
# 1  121  \n\n\n\n\nNORTHANGER ABBEY\n\n\nby\n\nJane Aus...
# 2  141  \n\n\n\n\nMANSFIELD PARK\n\n(1814)\n\n\nBy Jan...
# 3  158  \n\n\n\n\nEMMA\n\nBy Jane Austen\n\n\n\n\nVOLU...
# 4  161  \nSpecial thanks are due to Sharon Partridge f...

# %%
# how do we combine the two?
print(df['id'], bdf['id'])
# Out:
# 0       105.0
# 1       121.0
# 2       141.0
# 3       158.0
# 4       161.0
# 5       946.0
# 6      1212.0
# 7      1342.0
# 8     21839.0
# 9     25946.0
# 10    31100.0
# 11    33388.0
# 12    35151.0
# 13    35163.0
# 14    36777.0
# 15    37431.0
# 16    37634.0
# 17    42078.0
# 18    42671.0
# 19    45186.0
# Name: id, dtype: object 0       105
# 1       121
# 2       141
# 3       158
# 4       161
# 5       946
# 6      1212
# 7      1342
# 8     21839
# 9     25946
# 10    31100
# 11    33388
# 12    35151
# 13    35163
# 14    36777
# 15    37431
# 16    37634
# 17    42078
# 18    42671
# 19    45186
# Name: id, dtype: object

# %%
# lets fix that first id by stripping out the last two letters (.02)
# pandas string cleaning at https://pandas.pydata.org/pandas-docs/stable/text.html
df['fid'] = df['id'].str[:-2]
df['fid']
# Out:
# 0       105
# 1       121
# 2       141
# 3       158
# 4       161
# 5       946
# 6      1212
# 7      1342
# 8     21839
# 9     25946
# 10    31100
# 11    33388
# 12    35151
# 13    35163
# 14    36777
# 15    37431
# 16    37634
# 17    42078
# 18    42671
# 19    45186
# Name: fid, dtype: object

# %%
#how do we merge so we have metadata with text?
#left.merge(right, **kwargs)
austen_corpus = df.merge(bdf, left_on='fid', right_on="id")
austen_corpus.head()
# Out:
#            LCC                      _repo _version alternative_title  \
# 0  102  {'PR'}             Persuasion_105    0.2.0
# 1  116  {'PR'}       Northanger-Abbey_121    0.2.0
# 2  134  {'PR'}         Mansfield-Park_141    0.2.0
# 3  151  {'PR'}                   Emma_158    0.2.0
# 4  154  {'PR'}  Sense-and-Sensibility_161    0.2.0
#
#          author authoryearofbirth authoryearofdeath contributor  \
# 0  Austen, Jane              1775              1817
# 1  Austen, Jane              1775              1817
# 2  Austen, Jane              1775              1817
# 3  Austen, Jane              1775              1817
# 4  Austen, Jane              1775              1817
#
#                                               covers  \
# 0  [{'cover_type': 'archival', 'image_path': 'epu...
# 1  [{'cover_type': 'generated', 'image_path': 'co...
# 2  [{'cover_type': 'generated', 'image_path': 'co...
# 3  [{'cover_type': 'generated', 'image_path': 'co...
# 4  [{'cover_type': 'generated', 'image_path': 'co...
#
#                          ...                          type  \
# 0                        ...                          Text
# 1                        ...                          Text
# 2                        ...                          Text
# 3                        ...                          Text
# 4                        ...                          Text
#
#                                    url  \
# 0  http://www.gutenberg.org/ebooks/105
# 1  http://www.gutenberg.org/ebooks/121
# 2  http://www.gutenberg.org/ebooks/141
# 3  http://www.gutenberg.org/ebooks/158
# 4  http://www.gutenberg.org/ebooks/161
#
#                                            wikipedia  \
# 0  ['https://fi.wikipedia.org/wiki/Viisasteleva_s...
# 1  ['https://fi.wikipedia.org/wiki/Northanger_Abb...
# 2  ['https://fi.wikipedia.org/wiki/Kasvattityt%C3...
# 3  ['https://fi.wikipedia.org/wiki/Emma_(romaani)...
# 4  ['https://fi.wikipedia.org/wiki/J%C3%A4rki_ja_...
#
#                                              wp_info    wp_literary_genres  \
# 0  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 1  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 2  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
# 3  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...  ['Novel_of_manners']
# 4  {'http://www.w3.org/1999/02/22-rdf-syntax-ns#t...
#
#   wp_publication_date                                        wp_subjects  fid  \
# 0                      ['Novels_about_nobility', 'John_Murray_(publis...  105
# 1                      ['Novels_by_Jane_Austen', 'Novels_set_in_Somer...  121
# 2                      ['Novels_by_Jane_Austen', 'British_novels_adap...  141
# 3                      ['Novels_by_Jane_Austen', 'Novels_about_nobili...  158
# 4                      ['Debut_novels', 'Novels_by_Jane_Austen', 'Wor...  161
#
#   id_y                                               text
# 0  105  by Al Haines.\n\n\n\n\n\n\n\n\n\n\nPersuasion\...
# 1  121  \n\n\n\n\nNORTHANGER ABBEY\n\n\nby\n\nJane Aus...
# 2  141  \n\n\n\n\nMANSFIELD PARK\n\n(1814)\n\n\nBy Jan...
# 3  158  \n\n\n\n\nEMMA\n\nBy Jane Austen\n\n\n\n\nVOLU...
# 4  161  \nSpecial thanks are due to Sharon Partridge f...
#
# [5 rows x 49 columns]

# %%
#remove leading and trailing new lines
austen_corpus["textn"] = austen_corpus['text'].str.strip("\n")
austen_corpus['textn']
# Out:
# 0     by Al Haines.\n\n\n\n\n\n\n\n\n\n\nPersuasion\...
# 1     NORTHANGER ABBEY\n\n\nby\n\nJane Austen (1803)...
# 2     MANSFIELD PARK\n\n(1814)\n\n\nBy Jane Austen\n...
# 3     EMMA\n\nBy Jane Austen\n\n\n\n\nVOLUME I\n\n\n...
# 4     Special thanks are due to Sharon Partridge for...
# 5     LADY SUSAN\n\nby Jane Austen\n\n\n\n\nI\n\n\nL...
# 6     LOVE AND FREINDSHIP AND OTHER EARLY WORKS\n\n(...
# 7     PRIDE AND PREJUDICE\n\nBy Jane Austen\n\n\n\nC...
# 8                              Transcriber's Note:\n...
# 9     Online Distributed Proofreading Team at http:/...
# 10    THE WORKS OF JANE AUSTEN\n\n\n\nEdited by Davi...
# 11       Note de transcription:\n   Les erreurs clai...
# 12      Au lecteur\n\n  Madame de Montolieu a tradui...
# 13      Au lecteur\n\n  Madame de Montolieu a tradui...
# 14      Au lecteur\n\n  Cette version électronique r...
# 15    produced from scanned images of public domain ...
# 16      Au lecteur\n\n  Madame de Montolieu a tradui...
# 17    [Transcriber's Note: letters that were supersc...
# 18    generously made available by Internet Archive ...
# 19    YLPEYS JA ENNAKKOLUULO\n\nKirj.\n\nJane Austen...
# Name: textn, dtype: object

# %% [markdown]
# # Try with a different author
