# %% [markdown]
# # What if we want data from the Graduate Center Website?

# %% [markdown]
# The [Scrapy](https://scrapy.org/) library is designed to pull data from websites when there's no API or the API won't work. It's often worth trying [DownThemAll](https://www.downthemall.net/) first.
#
# If you haven't installed Scrapy yet, [open a terminal](https://github.com/GCDigitalFellows/installdri.github.io/blob/master/anaconda.md) and type:
# ```bash
# conda install -c conda-forge scrapy -y
# ```

# %%
# scrapy tutorial is at 
# https://docs.scrapy.org/en/latest/intro/tutorial.html
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
# this helps the scraper run in a notebook
# https://www.jitsejan.nl/using-scrapy-in-jupyter-notebook.html
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import scrapy

class GCSpider(scrapy.Spider):
    name = "gc"

    def start_requests(self):
        urls = ['https://www.gc.cuny.edu/Home', 
                'https://www.gc.cuny.edu/Prospective-Current-Students/Current-Students']
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        page = response.url.split("/")[-2]
        filename = f'gc-{page}.html'
        with open(filename, 'wb') as f:
            f.write(response.body)
        self.log('Saved file %s' % filename)

# %%
process = CrawlerProcess()
process.crawl(GCSpider)
process.start()
# Out:
# 2018-03-14 06:12:12 [scrapy.utils.log] INFO: Scrapy 1.5.0 started (bot: scrapybot)
# 2018-03-14 06:12:12 [scrapy.utils.log] INFO: Versions: lxml 4.1.1.0, libxml2 2.9.7, cssselect 1.0.3, parsel 1.4.0, w3lib 1.19.0, Twisted 17.9.0, Python 3.6.4 | packaged by conda-forge | (default, Dec 23 2017, 16:54:01) - [GCC 4.2.1 Compatible Apple LLVM 6.1.0 (clang-602.0.53)], pyOpenSSL 17.4.0 (OpenSSL 1.0.2n  7 Dec 2017), cryptography 2.1.4, Platform Darwin-15.6.0-x86_64-i386-64bit
# 2018-03-14 06:12:12 [scrapy.crawler] INFO: Overridden settings: {}
# 2018-03-14 06:12:13 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2018-03-14 06:12:13 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-03-14 06:12:13 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-03-14 06:12:13 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-03-14 06:12:13 [scrapy.core.engine] INFO: Spider opened
# 2018-03-14 06:12:13 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-03-14 06:12:13 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-03-14 06:12:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.gc.cuny.edu/Home> (referer: None)
# 2018-03-14 06:12:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.gc.cuny.edu/Prospective-Current-Students/Current-Students> (referer: None)
# 2018-03-14 06:12:14 [gc] DEBUG: Saved file gc-www.gc.cuny.edu.html
# 2018-03-14 06:12:14 [gc] DEBUG: Saved file gc-Prospective-Current-Students.html
# 2018-03-14 06:12:14 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-03-14 06:12:14 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 477,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 85638,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2018, 3, 14, 10, 12, 14, 992951),
#  'log_count/DEBUG': 5,
#  'log_count/INFO': 7,
#  'memusage/max': 67469312,
#  'memusage/startup': 67469312,
#  'response_received_count': 2,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2018, 3, 14, 10, 12, 13, 314092)}
# 2018-03-14 06:12:14 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# response

# %% [markdown]
# While scrapy supports really robust parsing, it requires understanding the xpath experessions language. Sometimes it's easier to just save the page and use [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) for the parsing. Install it using
# ```
# conda install -c conda-forge beautifulsoup4 -y
# ```

# %%
from bs4 import BeautifulSoup
# The file needs to be opened first and the file handle passed into soup
with open("gc-www.gc.cuny.edu.html") as html_doc:
    soup = BeautifulSoup(html_doc, 'lxml')

# %% [markdown]
# Soup is an html document that we can now traverse using the DOM ([Document Object Model](https://developer.mozilla.org/en-US/docs/Web/API/Document_Object_Model))
#
# https://github.com/taspinar/twitterscraper/blob/master/twitterscraper/tweet.py

# %%
soup
# Out:
# <!DOCTYPE html>
# <!-- paulirish.com/2008/conditional-stylesheets-vs-css-hacks-answer-neither/ --><!--[if lt IE 7 ]> <html class="no-js ie6"> <![endif]--><!--[if IE 7 ]>    <html class="no-js ie7"> <![endif]--><!--[if IE 8 ]>    <html class="no-js ie8"> <![endif]--><!--[if (gte IE 9)|!(IE)]><!--><html class="no-js"> <!--<![endif]-->
# <head id="head"><title>
# 	Home
# </title><meta content="The Graduate Center, The City University of New York
# Established in 1961, the Graduate Center of the City University of New York (CUNY) is devoted primarily to doctoral studies and awards most of CUNY's doctoral degrees. An internationally recognized center for advanced studies and a national model for public doctoral education, the Graduate Center offers more than thirty doctoral programs in the arts, humanities, social sciences, and the natural sciences, as well as a number of master's programs. Many of its faculty members are among the world's leading scholars in their respective fields. The school currently enrolls over 4700 students from throughout the United States, as well as from about eighty foreign countries, and its alumni hold major positions in industry and government, as well as in academia. The Graduate Center is also home to more than thirty interdisciplinary research centers and institutes focused on areas of compelling social, civic, cultural, and scientific concerns. Located in a landmark Fifth Avenue building, the Graduate Center has become a vital part of New York City's intellectual and cultural life with its extensive array of public lectures, exhibitions, concerts, and theatrical events. Further information on the Graduate Center and its programs can be found at www.gc.cuny.edu." name="description"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <meta content="text/css" http-equiv="content-style-type"/>
# <meta content="text/javascript" http-equiv="content-script-type"/>
# <meta content="graduate school, doctoral programs, master's programs, new york city, certificate studies, manhattan, cuny, city university of new york, research centers, interdisciplinary certificates, science schools, academic experts, graduate center, cuny
# graduate center, 365 newsletter" name="keywords"/>
# <meta charset="utf-8"/>
# <!-- Always force latest IE rendering engine (even in intranet) & Chrome Frame
# Remove this if you use the .htaccess -->
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache, must-revalidate, no-store, post-check=0, pre-check=0" http-equiv="cache-control"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="" name="author"/>
# <meta content="hqWcI7LGCrnlZuZ3iNTV1AoNvUfzSmis9QzWohJ9nHo" name="google-site-verification"/>
# <!-- Mobile viewport optimized: j.mp/bplateviewport -->
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <!-- Place favicon.ico & apple-touch-icon.png in the root of your domain and delete these references -->
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="/shared/css/cuny-all.css?v=2016-1-19" rel="stylesheet"/>
# <link href="/shared/css/directory.css?v=2016-1-19" rel="stylesheet"/>
# <link href="/shared/css/print.css?v=2016-1-19" media="print" rel="stylesheet" type="text/css"/>
# <link href="/shared/font-awesome/css/font-awesome.min.css?v=2016-1-19" rel="stylesheet"/>
# <!-- All JavaScript at the bottom, except for Modernizr which enables HTML5 elements & feature detects -->
# <script src="/shared/js/libs/modernizr.custom.49951.js"></script>
# <!-- Initialize bodyClass variable. Only used with templates requiring a unique class in the body tag -->
# <script type="text/javascript">
# var ajaxConfig = new Array();
# var calendarConfig = new Array();
# var bodyClass = "";
# var mainContentClass = "";
# var currentSection = "";
# var showFullBottom = "false";
# var showFullTop = "false";
# var showalert = "false";
# var showFullBottomHome = "false";
# var showMainAlt = "false";
# var showHomePage2 = "false";
# var showLeftColumn = "true";
# var showRightColumn = "true";
# var showMainColumn = "true";
# var showMiddleColumn = "false";
# var showTwoColumnDiv = "false";
# var showTwoColumnAside = "false";
# var showMainContentII = "false";
# var isMultiCarousel = "false";
# var isGroupedPseudoAccordions = "false";
# var setupHomePage = "false";
# var setuphomeimage = "false";
# var setupNoMenu = "false";
# var setupTwoColumn = "false";
# var isAccordion = "false";
# var runCalendarSetup = "false";
# var runDirectorySearchSetup = "false";
# var runSubDirectorySetup = "false";
# </script>
# <!-- Google Analytics -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-30300805-1', 'cuny.edu');
#   ga('require', 'linkid');
#   ga('send', 'pageview');
#
# </script>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# </head><body class="LTR ENUS ContentBody" lang="en">
# <form action="/Home" id="form" method="post">
# <input id="__CMSCsrfToken" name="__CMSCsrfToken" type="hidden" value="1QJxggyG0QFY6bsTb3f7owUdtFcLMyS0SSJQn3ebeQxFYen9N+f3qdAQ5jPhvyx/Oilm2Mpjc78H76h86M3d9fZLRQs="/>
# <input id="lng" name="lng" type="hidden" value="en-US"/>
# <script type="text/javascript">
# 	//<![CDATA[
#
# function PM_Postback(param) { if (window.top.HideScreenLockWarningAndSync) { window.top.HideScreenLockWarningAndSync(1080); } if(window.CMSContentManager) { CMSContentManager.allowSubmit = true; }; __doPostBack('m$am',param); }
# function PM_Callback(param, callback, ctx) { if (window.top.HideScreenLockWarningAndSync) { window.top.HideScreenLockWarningAndSync(1080); }if (window.CMSContentManager) { CMSContentManager.storeContentChangedStatus(); };WebForm_DoCallback('m$am',param,callback,ctx,null,true); }
# //]]>
# </script>
# <script src="/ScriptResource.axd?d=x6wALODbMJK5e0eRC_p1LT2N24n8qblbM8mFbCbwdaTBIfUh3N9YCJN624YG4j-8JJaaFT6WpR1YyDrvMmG2Lt5-2qSfTRS3fyJdKQlnk1XxXOPO0&amp;t=7c776dc1" type="text/javascript"></script>
# <script type="text/javascript">
# 	//<![CDATA[
#
# var CMS = CMS || {};
# CMS.Application = {
#   "isRTL": "false",
#   "isDebuggingEnabled": false,
#   "applicationUrl": "/",
#   "imagesUrl": "/CMSPages/GetResource.ashx?image=%5bImages.zip%5d%2f",
#   "isDialog": false
# };
#
# //]]>
# </script>
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="A5343185"/>
# <div id="ctxM">
# </div>
# <!-- Google Tag Manager -->
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-M4PVDV" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script>
#   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                                                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                       })(window,document,'script','dataLayer','GTM-M4PVDV');
# </script>
# <!-- End Google Tag Manager -->
# <div class="visuallyhidden" id="skip">
# <a href="#main-content">Skip to Main Content</a>
# </div>
# <!-- PAGE START -->
# <div class="page">
# <!-- HEADER START -->
# <header>
# <header id="p_lt_ccHeader_genHeader">
# <div class="ir" id="site-logo">
# <a href="/home" title="Graduate Center, CUNY">
# <img alt="Graduate Center, CUNY logo" height="150" src="/shared/images/shared/CUNY-GC-logo.png" width="85"/></a>
# </div>
# <nav class="clearfix" id="service-nav">
# <ul class="service-menu">
# <li><a href="/GC-Header/Directory" title="Graduate Center Directory">Directory</a></li>
# <li><a href="/GC-Header/Calendar" title="Calendar">Calendar</a></li>
# <li><a href="/GC-Header/GC-Portal" title="GC Portal">GC Portal</a></li>
# <li><a href="/GC-Header/Admissions" title="Admissions">Admissions</a></li>
# <li><a href="/GC-Header/Alumni" title="Alumni">Alumni</a></li>
# <li><a href="/GC-Header/Library" title="GC Library">Library</a></li>
# <li><a href="/GC-Header/IT" title="Information Technology">IT</a></li>
# <li><a href="/GC-Header/Diversity" title="Diversity">Diversity</a></li>
# <li><a href="/GC-Header/HR" title="Human Resources">HR</a></li>
# <li><a href="/GC-Header/Title-IX" title="Title IX">Title IX</a></li>
# </ul>
# </nav>
# <div class="search-wrapper" id="search">
# <input class="button ir search-button" id="main-search-button" type="button" value="Search"/>
# <input autocomplete="off" class="search form-text search-input search-input-text" id="main-search-box" name="q" placeholder="Search" type="text"/>
# </div>
# <div class="social-logo-wrapper" id="social-logo">
# <a href="/Facebook" target="_blank" title="Graduate Center Facebook">
# <img alt="Facebook Logo" src="/shared/images/shared/logo_facebook_25px.png"/>
# </a>
# <a href="/Twitter" target="_blank" title="Graduate Center Twitter">
# <img alt="Twitter Logo" src="/shared/images/shared/logo_twitter_25px.png"/>
# </a>
# <a href="/YouTube" target="_blank" title="Graduate Center YouTube">
# <img alt="YouTube Logo" src="/shared/images/shared/YouTube_25px_25px.png"/>
# </a>
# <a href="/LinkedIn" target="_blank" title="Graduate Center LinkedIn">
# <img alt="LinkedIn Logo" src="/shared/images/shared/LinkedIn_25px_25px.png"/>
# </a>
# <a href="/Instagram" target="_blank" title="Graduate Center Instagram">
# <img alt="Instagram Logo" src="/shared/images/shared/Instagram_Icon_25px_25px.png"/>
# </a>
# <a href="/RSS" title="Graduate Center RSS">
# <img alt="RSS Logo" src="/shared/images/shared/logo_feed_25px.png"/>
# </a>
# </div>
# <nav class="clearfix" id="gc-nav">
# <div id="gc-nav-container">
# <ul id="gc-nav">
# <li id="menu-degrees">
# <a class="info-btn" href="/Degrees-Research" title="Degrees &amp; Research"><h4>DEGREES<br/>&amp; RESEARCH</h4></a>
# <div class="sub-nav-container">
# <div class="sub-nav-items">
# <div class="unit size1of4">
# <ul>
# <li><u><a href="/Degrees-Research/Doctoral-Programs">Doctoral Programs</a></u></li>
# <li><u><a href="/Degrees-Research/Master-s-Programs">Master's Programs</a></u></li>
# <li><u><a href="/Degrees-Research/The-Advanced-Research-Collaborative">Advanced Research Collaborative</a></u></li>
# <li><u><a href="/Degrees-Research/Centers-Institutes">Centers &amp; Institutes</a></u></li>
# <li><u><a href="/Degrees-Research/Initiatives-Committees">Initiatives &amp; Committees</a></u></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li id="menu-students">
# <a class="info-btn" href="/Prospective-Current-Students" title="Prospective &amp; Current Students"><h4>PROSPECTIVE<br/>&amp; CURRENT<br/>STUDENTS</h4></a>
# <div class="sub-nav-container">
# <div class="sub-nav-items">
# <div class="unit size1of4">
# <ul>
# <li><a href="/Prospective-Current-Students/Prospective-Students.aspx"><u>Prospective Students</u></a></li>
# <li><a href="/Prospective-Current-Students/Current-Students"><u>Current Students</u></a></li>
# <li><a href="/Prospective-Current-Students/Student-Life"><u>Student Life</u></a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li id="menu-faculty">
# <a class="info-btn" href="/Faculty" title="Faculty"><h4>FACULTY</h4></a>
# <div class="sub-nav-container">
# <div class="sub-nav-items">
# <div class="unit size1of4">
# <ul>
# <li><a href="/Faculty/Faculty-News"><u>Faculty News</u></a></li>
# <li><a href="/Faculty/Books"><u>Books</u></a></li>
# <li><a href="/Faculty/Profiles"><u>Profiles</u></a></li>
# <li><a href="/Faculty/Resources"><u>Resources</u></a></li>
# <li><a href="/Faculty/Title-IX-Awareness"><u>Title IX Awareness</u></a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li id="menu-pub-prog">
# <a class="info-btn" href="/Public-Programming" title="Public Programming"><h4>PUBLIC<br/>PROGRAMMING</h4></a>
# <div class="sub-nav-container">
# <div class="sub-nav-items">
# <div class="unit size1of4">
# <ul>
# <li><a href="/All-GC-Events/GC-Presents"><u>GC Presents</u></a></li>
# <li><a href="/All-GC-Events/Calendar"><u>Calendar</u></a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li id="menu-news">
# <a class="info-btn" href="/News" title="News"><h4>NEWS</h4></a>
# <div class="sub-nav-container">
# <div class="sub-nav-items">
# <div class="unit size1of4">
# <ul>
# <li><a href="/News/All-News"><u>All News</u></a></li>
# <li><a href="/News//Student-News"><u>Student News</u></a></li>
# <li><a href="/News/Faculty-News"><u>Faculty News</u></a></li>
# <li><a href="/News/Alumni-News"><u>Alumni News</u></a></li>
# <li><a href="/News/Announcements"><u>Announcements</u></a></li>
# <li><a href="/News/Research-News"><u>Research News</u></a></li>
# <li><a href="/News/Research-Grant-News"><u>Research Grant News</u></a></li>
# <li><a href="/News/Podcasts"><u>Podcasts</u></a></li>
# <li><a href="/News/Press-Coverage"><u>Press Coverage</u></a></li>
# <li><a href="/News/Press-Room"><u>Press Room</u></a></li>
# <li><a href="/News/365-Fifth"><u><em>365 Fifth</em> E-Newsletter</u></a></li>
# <li><a href="/About-the-GC/Administrative-Services/Office-of-Communications-Marketing"><u>Office of Communications and Marketing</u></a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li id="menu-support">
# <a class="info-btn" href="/Support-the-GC" title="Support the GC"><h4>SUPPORT THE GC</h4></a>
# <div class="sub-nav-container">
# <div class="sub-nav-items">
# <div class="unit size1of4">
# <ul>
# <li><a href="/Support-the-GC/Ways-to-Give"><u>Ways to Give</u></a></li>
# <li><a href="/Support-the-GC/Foundation"><u>Foundation</u></a></li>
# <li><a href="/Support-the-GC/Community-Membership"><u>Community Membership</u></a></li>
# <li><a href="/Support-the-GC/Planned-Giving"><u>Planned Giving</u></a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li id="menu-about">
# <a class="info-btn" href="/About-the-GC" title="About the GC"><h4>ABOUT THE GC</h4></a>
# <div class="sub-nav-container">
# <div class="sub-nav-items">
# <div class="unit size1of4">
# <ul>
# <li><a href="/About-the-GC/Institutional-Profile"><u>Institutional Profile</u></a></li>
# <li><a href="/About-the-GC/GC-Leadership"><u>GC Leadership</u></a></li>
# <li><a href="/About-the-GC/President-s-Office"><u>President's Office</u></a></li>
# <li><a href="/About-the-GC/Provosts-Office"><u>Provost's Office</u></a></li>
# <li><a href="/About-the-GC/Diversity-and-Inclusion"><u>Diversity and Inclusion</u></a></li>
# <li><a href="/About-the-GC/Administrative-Services"><u>Administrative Services</u></a></li>
# <li><a href="/About-the-GC/Building-Venues-Particulars"><u>Building Venues &amp; Particulars</u></a></li>
# <li><a href="/About-the-GC/Administrative-Services/Business-Finance/Financial-Information"><u>Financial Information</u></a></li>
# <li><a href="/About-the-GC/University-Center-Academic-Entities"><u>University Center Academic Entities</u></a></li>
# <li><a href="/About-the-GC/Administrative-Services/Governance-Policies-Procedures"><u>Governance, Policies &amp; Procedures</u></a></li>
# <li><a href="/About-the-GC/Administrative-Services/FAQ"><u>FAQ</u></a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <script type="text/javascript">
# 	currentSection = "";
# </script>
# </nav>
# </header>
# <script type="text/javascript">
# 	miniSiteTitle = "";
# </script>
# </header>
# <!-- HEADER END -->
# <!-- BODY START -->
# <div class="body">
# <!-- ***FULL WIDTH TOP START*** -->
# <div class="mainNolines" id="FullTop">
# </div>
# <!-- FULL WIDTH TOP END -->
# <!-- LEFT COLUMN START -->
# <div class="leftCol cunyCols" id="LeftColumn">
# <script type="text/javascript">
#   showHomePage2= "true";
#   showalert= "true";
#   setuphomeimage= "true";
#   showFullBottomHome= "true";
#   showMainColumn= "false";
#   showLeftColumn= "false";
# </script>
# <div class="mod menuLeftNav" id="p_lt_ccLeftNav_Hybrid_divTreeview">
# <div class="inner">
# <div class="hd">
# <h3 class="tree-header"><a class="keyboardAccess" href="http://www.gc.cuny.edu">Home</a></h3>
# </div>
# <div class="bd">
# <ul><li><span>Home</span><ul></ul></li><li><a href="/Degrees-Research">Degrees &amp; Research</a></li><li><a href="/Prospective-Current-Students">Prospective &amp; Current Students</a></li><li><a href="/Faculty">Faculty</a></li><li><a href="/All-GC-Events">All GC Events</a></li><li><a href="/Support-the-GC">Support the GC</a></li><li><a href="/About-the-GC">About the GC</a></li><li><a href="/News">News</a></li></ul>
# </div>
# </div>
# </div>
# </div>
# <!-- LEFT COLUMN END -->
# <!-- TWO COLUMN HEADER (ASIDE TAG) START -->
# <aside class="mod twoColumnHeader">
# </aside>
# <!-- TWO COLUMN HEADER (ASIDE TAG) END -->
# <!-- TWO COLUMN HEADER (DIV TAG) START -->
# <div class="mod twoColumnHeader">
# </div>
# <!-- TWO COLUMN HEADER (DIV TAG) END -->
# <!-- MIDDLE COLUMN START -->
# <article class="middleCol cunyCols" id="MiddleColumn">
# </article>
# <!-- MIDDLE COLUMN END -->
# <!-- RIGHT COLUMN START -->
# <div class="rightCol cunyCols" id="RightColumn">
#
#
#
# 		</div>
# <!-- RIGHT COLUMN END -->
# <!-- ***MAIN CONTENT ALT START*** -->
# <div class="main" id="MainAlt">
#
#
#
# 		</div>
# <!-- ***MAIN CONTENT ALT END*** -->
# <!-- ***NEW HOME PAGE** -->
# <div class="mainNoLines" id="HomePage2">
# <div id="alert">
# </div>
# <div id="spotlightboxes1">
# <div id="sliderbox2">
# <div style="clear:both;"> </div><div class="carousel-wrapper" data-caption="True" data-fade="True" id="52bdb546-57a3-40e8-81ae-9af52f843526" rel="4000" style="position:relative; width:840px;Height:660px; clear:both;">
# <img alt="" data-href="Degrees-Research/Master-s-Programs?utm_source=gcsite&amp;utm_medium=carouselSlide2&amp;utm_campaign=hpfeature" data-secondary="" data-target="internal" src="/CUNY_GC/media/CUNY-Graduate-Center/Images/Home/NEWHPCarousel/GC_MA_HP_SLIDE_840px_660px.jpg?ext=.jpg" style="cursor:pointer;"/><img alt="" data-href="Degrees-Research/Doctoral-Programs?utm_source=gcsite&amp;utm_medium=carouselSlide1&amp;utm_campaign=hpfeature" data-secondary="" data-target="internal" src="/CUNY_GC/media/CUNY-Graduate-Center/Images/Home/NEWHPCarousel/GC_DE_HP_SLIDE_840px_660px.jpg?ext=.jpg" style="cursor:pointer;"/><img alt="" data-href="https://twitter.com/gc_cuny?utm_source=gcsite&amp;utm_medium=carouselSlide3&amp;utm_campaign=hpfeature" data-secondary="" data-target="external" src="/CUNY_GC/media/CUNY-Graduate-Center/Images/Home/NEWHPCarousel/GC_SOCIAL_HP_SLIDE_840px_660px.jpg?ext=.jpg" style="cursor:pointer;"/><img alt="" data-href="All-GC-Events/GC-Presents?utm_source=gcsite&amp;utm_medium=carouselSlide4&amp;utm_campaign=hpfeature" data-secondary="" data-target="internal" src="/CUNY_GC/media/CUNY-Graduate-Center/Images/Home/NEWHPCarousel/GC_CONVERSATION_HP_SLIDE_840px_660px.jpg?ext=.jpg" style="cursor:pointer;"/>
# </div>
# </div>
# </div>
# <div id="spotlightboxes2">
# <div id="studentbox2">
# <p>
# </p><div class="featureboxesBlue"><a href="/News/All-News/Detail?id=44026&amp;utm_source=gcsite&amp;utm_medium=news&amp;utm_campaign=hpfeature"><img alt="Call Me By Your Name" src="/CUNY_GC/media/CUNY-Graduate-Center/Images/Home/news/CallmebyCoverArt_390px_200px.jpg"/></a>
# <div class="featureboxesTitle"><a href="/News/All-News/Detail?id=44026&amp;utm_source=gcsite&amp;utm_medium=news&amp;utm_campaign=hpfeature">The Oscar Goes To …</a></div>
# <p><em>Call Me By Your Name</em>, the film adaptation of Graduate Center Professor André Aciman’s novel, won the Academy Award for best adapted screenplay.</p>
# </div>
# </div>
# <div id="facultybox2">
# <p>
# </p><div class="featureboxesBlue"><a href="/News/All-News/Detail?id=43660&amp;utm_source=gcsite&amp;utm_medium=news&amp;utm_campaign=hpfeature"><img alt="Tania León" src="/CUNY_GC/media/CUNY-Graduate-Center/Images/Home/news/tania_leon_390px_200px.jpg"/></a>
# <div class="featureboxesTitle"><a href="/News/All-News/Detail?id=43660&amp;utm_source=gcsite&amp;utm_medium=news&amp;utm_campaign=hpfeature">Something to Sing About</a></div>
# <p>Professor Tania León, a celebrated composer and conductor, reflects on her latest accolade — a major award from United States Artists.</p>
# </div>
# </div>
# <div id="researchbox2">
# <p>
# </p><div class="featureboxesBlue"><a href="/News/All-News/Detail?id=43656&amp;utm_source=gcsite&amp;utm_medium=news&amp;utm_campaign=hpfeature"><img alt="Do Lee" src="/CUNY_GC/media/CUNY-Graduate-Center/Images/Home/news/do_lee_390px_200px.jpg"/></a>
# <div class="featureboxesTitle"><a href="/News/All-News/Detail?id=43656&amp;utm_source=gcsite&amp;utm_medium=news&amp;utm_campaign=hpfeature">E-Bikes and Immigrants</a></div>
# <p>Ph.D. candidate Do Lee has become an advocate for electric bikes and the immigrant workers who rely on them.</p>
# </div>
# <br/>
#
# 				</div>
# <div id="featuredweeklybox2">
# <p>
# </p><div class="featureboxesBlue"><a href="/News/All-News/Detail?id=43658&amp;utm_source=gcsite&amp;utm_medium=news&amp;utm_campaign=hpfeature"><img alt="Julia Castello" src="/CUNY_GC/media/CUNY-Graduate-Center/Images/Home/news/Julia_Castello_390px_200px.jpg"/></a>
# <div class="featureboxesTitle"><a href="/News/All-News/Detail?id=43658&amp;utm_source=gcsite&amp;utm_medium=news&amp;utm_campaign=hpfeature">New Hope for Treating Depression</a></div>
# <p>Research by Ph.D. candidate Julia Castello could lead to needed new antidepressants.</p>
# </div>
#
# 				</div>
# </div>
# <div id="spotlightboxes3">
# <div class="homefull" id="FullBottomHome">
# <div>
# <div class="featuredEventBoxStart"><div class="featuredEventStart">FEATURED EVENTS<a href="http://www.gc.cuny.edu/Public-Programming/Calendar">More Events <i class="fa fa-arrow-circle-right"></i></a></div></div><div class="featuredEventBox">
# <div class="featuredEventdate"> Fri., Mar. 16
#   </div>
# <div class="featuredEventTitle"><a href="/News-Events-Public-Programs/Calendar/Detail?id=43709&amp;utm_source=gcsite&amp;utm_medium=cal&amp;utm_campaign=hpfeature"> The Voice of Venezuela: Betsayda Machado y La Parranda</a></div>
# </div><div class="featuredEventBox">
# <div class="featuredEventdate"> Tue., Mar. 20
#   </div>
# <div class="featuredEventTitle"><a href="/News-Events-Public-Programs/Calendar/Detail?id=44287&amp;utm_source=gcsite&amp;utm_medium=cal&amp;utm_campaign=hpfeature"> Lost &amp; Found: The CUNY Poetics Document Initiative Series VII Launch</a></div>
# </div><div class="featuredEventBox">
# <div class="featuredEventdate"> Wed., Mar. 21
#   </div>
# <div class="featuredEventTitle"><a href="/News-Events-Public-Programs/Calendar/Detail?id=43710&amp;utm_source=gcsite&amp;utm_medium=cal&amp;utm_campaign=hpfeature"> The Gourmands' Way: Six Americans in Paris and the Birth of a New Gastronomy</a></div>
# </div><div class="featuredEventBox">
# <div class="featuredEventdate"> Fri., Mar. 23
#   </div>
# <div class="featuredEventTitle"><a href="/News-Events-Public-Programs/Calendar/Detail?id=43871&amp;utm_source=gcsite&amp;utm_medium=cal&amp;utm_campaign=hpfeature"> Musical Dynasties: A Conversation with the Habichuela Clan</a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- ***NEW HOME PAGE END*** -->
# <article class="main" id="main-content">
# <noscript>
# <div class="browser-warning">
# 				For full functionality of this site it is necessary to enable JavaScript.
# 				Here are the <a href="http://www.enable-javascript.com/" target="_blank">
# 				instructions how to enable JavaScript in your web browser</a>.
# 				</div>
# </noscript>
# <!-- MAIN CONTENT START -->
# <h1></h1>
# <div id="MainContentII">
# </div>
# <!-- MAIN CONTENT END -->
# </article>
# <!-- ***FULL WIDTH BOTTOM START -->
# <div class="mainNolines" id="FullBottom">
# </div>
# <!-- ***FULL WIDTH BOTTOM END -->
# </div>
# <!-- BODY END -->
# <!-- FOOTER START -->
# <footer class="line footer-line">
# <div class="line">
# <div class="unit size1of4">
#
# 			</div>
# <div class="unit size3of4 lastUnit">
# <div class="line">
# <div class="unit size1of3">
# <h3 class="feint">Quick links:</h3>
# <ul>
# <li>
# <a href="http://www.cuny.edu/" target="_blank">CUNY</a>
# </li>
# <li>
# <a href="https://home.cunyfirst.cuny.edu/oam/Portal_Login1.html" target="_blank">CUNYfirst</a>
# </li>
# <li>
# <a href="/Privacy">Privacy</a>
# </li>
# <li>
# <div id="__ba_panel"></div>
# </li>
# <li>
# <a class="textonly" href="http://www2.cuny.edu/accessibility/assistive-technology/text-version/" target="_blank">Text-Only Version</a>
# </li>
# <li>
# <a href="/Report-an-Issue">Report an Issue</a>
# </li>
# <li>
# <a href="/About-the-GC/Administrative-Services/Compliance-and-Diversity/Compliance-and-Diversity-Policies-and-Procedures/Detail?id=30015">Notice of Non-Discrimination</a>
# </li>
# </ul>
# </div>
# <div class="unit size1of3">
# <h3 class="feint">Contact us:</h3>
# <div class="vcard">
# <p class="adr">
# <span class="street-address">The Graduate Center, CUNY</span>
# <br/>
# <span class="street-address">365 Fifth Avenue</span>
# <br/>
# <span class="region">New York, NY</span>
# <span class="postal-code"> 10016</span>
# <span class="country-name">USA</span>
# </p>
# <p>
# <span class="tel">
# <span class="value">1-877-428-6942</span>
# </span> |
# 								<span class="tel">
# <span class="value">(212) 817-7000</span>
# </span>
# <br/>
# 								Skype: <a href="skype:gc.cuny.edu?call">gc.cuny.edu</a>
# <br/>
# <a href="/About-the-GC/Building-Particulars/Security-Public-Safety">Campus Security</a> ext 7777
# 							</p>
# <p class="fn">©
# 								2018 The Graduate Center
# 							</p>
# </div>
# </div>
# <div class="unit size1of3 lastUnit">
# <div class="cuny-block-logo ir" id="cunystore-logo">
# <a href="http://www1.cuny.edu/sites/title-ix/?post_type=campus_profile&amp;p=144" target="_blank" title="Enough is Enough: Combating Sexual Misconduct">
# <img alt="Enough is Enough: Combating Sexual Misconduct" height="56px" src="/CUNY_GC/media/CUNY-Graduate-Center/Images/Homepage%20Footer/Enough_is_enough_240x56.png" width="240px"/>
# </a>
# </div>
# <div class="cuny-block-logo ir">
# <a href="http://www.cuny.edu" target="_blank" title="CUNY Central">
# <img alt="CUNY Central" height="56px" src="/shared/images/shared/cuny_footer_logo.png" width="230px"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <!-- FOOTER END -->
# </div>
# <!-- PAGE END -->
# <!-- SCRIPTS START -->
# <!-- Grab Google CDN's jQuery. fall back to local if necessary -->
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.5.1/jquery.min.js"></script>
# <script>!window.jQuery && document.write(unescape('%3Cscript src="shared/js/libs/jquery-1.5.1.min.js"%3E%3C/script%3E'))</script>
# <!-- scripts concatenated and minified via ant build script-->
# <script src="/shared/js/jquery-ui-1.8.14.custom.min.js" type="text/javascript"></script>
# <script src="/shared/js/plugins.js" type="text/javascript"></script>
# <script src="/shared/js/script.js" type="text/javascript"></script>
# <script src="/shared/js/jquery.slide.js?ver=2" type="text/javascript"></script>
# <script src="/shared/js/bmm.js?ver=6" type="text/javascript"></script>
# <script src="/shared/js/jquery-ext-2.1.7.js" type="text/javascript"></script>
# <script src="/shared/js/jquery.datatable.js" type="text/javascript"></script>
# <script type="text/javascript">var switchTo5x=true;</script>
# <script src="https://ws.sharethis.com/button/buttons.js" type="text/javascript"></script>
# <script type="text/javascript">stLight.options({publisher:'b1a171a7-19e5-4857-a0e6-3e223717d1b2'});</script>
# <!--
# <script type="text/javascript">var _baTheme=0, _baMode='Make this Website Talk', _baUseCookies=true, _baHideOnLoad=false;</script>
# <script type="text/javascript" src="//www.browsealoud.com/plus/scripts/ba.js"></script>
# -->
# <script src="/shared/js/accessibility.min.js" type="text/javascript"></script>
# <script src="/CMSScripts/Custom/kentico-quirks.js" type="text/javascript"></script>
# <!-- end concatenated and minified scripts-->
# <!--[if lt IE 7 ]>
# <script src="shared/js/libs/dd_belatedpng.js"></script>
# <script>DD_belatedPNG.fix('img, .png_bg'); // Fix any <img> or .png_bg bg-images. Also, please read goo.gl/mZiyb </script>
# <![endif]-->
# <!-- SCRIPTS END -->
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# <script type="text/javascript">
#       //<![CDATA[
#       if (window.WebForm_InitCallback) {
#         __theFormPostData = '';
#         __theFormPostCollection = new Array();
#         window.WebForm_InitCallback();
#       }
#       //]]>
#     </script>
# </form>
# </body>
# </html>

# %%
# any attribute of the DOM is also an attribute the soup object
soup.meta
# Out:
# <meta content="The Graduate Center, The City University of New York
# Established in 1961, the Graduate Center of the City University of New York (CUNY) is devoted primarily to doctoral studies and awards most of CUNY's doctoral degrees. An internationally recognized center for advanced studies and a national model for public doctoral education, the Graduate Center offers more than thirty doctoral programs in the arts, humanities, social sciences, and the natural sciences, as well as a number of master's programs. Many of its faculty members are among the world's leading scholars in their respective fields. The school currently enrolls over 4700 students from throughout the United States, as well as from about eighty foreign countries, and its alumni hold major positions in industry and government, as well as in academia. The Graduate Center is also home to more than thirty interdisciplinary research centers and institutes focused on areas of compelling social, civic, cultural, and scientific concerns. Located in a landmark Fifth Avenue building, the Graduate Center has become a vital part of New York City's intellectual and cultural life with its extensive array of public lectures, exhibitions, concerts, and theatrical events. Further information on the Graduate Center and its programs can be found at www.gc.cuny.edu." name="description"/>

# %%
soup.find_all('meta')
# Out:
# [<meta content="The Graduate Center, The City University of New York
#  Established in 1961, the Graduate Center of the City University of New York (CUNY) is devoted primarily to doctoral studies and awards most of CUNY's doctoral degrees. An internationally recognized center for advanced studies and a national model for public doctoral education, the Graduate Center offers more than thirty doctoral programs in the arts, humanities, social sciences, and the natural sciences, as well as a number of master's programs. Many of its faculty members are among the world's leading scholars in their respective fields. The school currently enrolls over 4700 students from throughout the United States, as well as from about eighty foreign countries, and its alumni hold major positions in industry and government, as well as in academia. The Graduate Center is also home to more than thirty interdisciplinary research centers and institutes focused on areas of compelling social, civic, cultural, and scientific concerns. Located in a landmark Fifth Avenue building, the Graduate Center has become a vital part of New York City's intellectual and cultural life with its extensive array of public lectures, exhibitions, concerts, and theatrical events. Further information on the Graduate Center and its programs can be found at www.gc.cuny.edu." name="description"/>,
#  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>,
#  <meta content="no-cache" http-equiv="pragma"/>,
#  <meta content="text/css" http-equiv="content-style-type"/>,
#  <meta content="text/javascript" http-equiv="content-script-type"/>,
#  <meta content="graduate school, doctoral programs, master's programs, new york city, certificate studies, manhattan, cuny, city university of new york, research centers, interdisciplinary certificates, science schools, academic experts, graduate center, cuny
#  graduate center, 365 newsletter" name="keywords"/>,
#  <meta charset="utf-8"/>,
#  <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>,
#  <meta content="no-cache, must-revalidate, no-store, post-check=0, pre-check=0" http-equiv="cache-control"/>,
#  <meta content="-1" http-equiv="Expires"/>,
#  <meta content="" name="author"/>,
#  <meta content="hqWcI7LGCrnlZuZ3iNTV1AoNvUfzSmis9QzWohJ9nHo" name="google-site-verification"/>,
#  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>]

# %%
#attributes of the tag are treated as dictionary (key, value pairs)
soup.meta['content']
# Out:
# "The Graduate Center, The City University of New York\nEstablished in 1961, the Graduate Center of the City University of New York (CUNY) is devoted primarily to doctoral studies and awards most of CUNY's doctoral degrees. An internationally recognized center for advanced studies and a national model for public doctoral education, the Graduate Center offers more than thirty doctoral programs in the arts, humanities, social sciences, and the natural sciences, as well as a number of master's programs. Many of its faculty members are among the world's leading scholars in their respective fields. The school currently enrolls over 4700 students from throughout the United States, as well as from about eighty foreign countries, and its alumni hold major positions in industry and government, as well as in academia. The Graduate Center is also home to more than thirty interdisciplinary research centers and institutes focused on areas of compelling social, civic, cultural, and scientific concerns. Located in a landmark Fifth Avenue building, the Graduate Center has become a vital part of New York City's intellectual and cultural life with its extensive array of public lectures, exhibitions, concerts, and theatrical events. Further information on the Graduate Center and its programs can be found at www.gc.cuny.edu."

# %% [markdown]
# # find the content of the meta
